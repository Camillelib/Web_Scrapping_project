# %% [markdown]
# # Scrapping Carrefour promotions

# %%
# import libraries
import requests as r
import json
import pandas as pd
from bs4 import BeautifulSoup
import os

# %% [markdown]
# ### Finding out how many pages need to be scrapped
# Steps:
# - total number of product promoted
# - divided by number of product per page
# - round up to get the total number of promotion pages

# %%
url='https://www.carrefour.fr/promotions?noRedirect=0&page=0'
html = r.get(url).content;
soup = BeautifulSoup(html)

# i = number of products promoted
number=[i.text.replace('\n','') for i in soup.select('h5')]
i=int(number[0].split()[0])
print(i)

# checking number of product per page
product_name=[i.text.replace('\n','') for i in soup.select('ul h2')]
print(len(product_name))

import math
# n = number of pages of promo
n=math.ceil(i/60)
n
# Out:
# 322
# 60
# 6

# %%
import time
df_final=pd.DataFrame()
n=6

for i in range(n+1):
    url=f'https://www.carrefour.fr/promotions?noRedirect=0&page={i}'
    headers=f"""accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
cookie: TCPID=119551614271772534656; _ga=GA1.2.1334375845.1556892869; cookieIDCrfOne=V12019531614280.2021166067845266; TC_OPTOUT=0@@@@@@ALL; already_visitedOne=1; visid_incap_1982952=0RjOMFJXRuKKO5znr4FgKeRMzFwAAAAAQUIPAAAAAAD6n2mvQU/sqwDmJkARHJBk; tc_cj_v2=m_iZZZ%22**%22%27%20ZZZKOOPRSLRPQNRRZZZ%5D777_rn_lh%5BfyfcheZZZ222H.*-/%24-%7B+%7B-%24.H%7D*%28ZZZKOOQLKRRRQLLMZZZ%5D777m_iZZZ%22**%22%27%20ZZZKOQRKMKMSQNRKZZZ%5D; datadome=MV~uTOOCnVIzfg.ULn2qjQwiYrYCKiCPqVlIXhkojIZNBB1zJzAjb_LCHT2CCYufdPeKF5Omu7~Z9jwshB52Hgn-fgLks.1wkrj4LccckQ; _cs_c=0; _cs_id=9566bfd8-1a78-a240-f0bb-e8015b3551ba.1556892869.3.1578131399.1578131399.1.1591056869072; visid_incap_441619=vrnUei+7RLiL2Xr3UUmTzfgij14AAAAAQUIPAAAAAABOtZUZlXTnCzjXe1PMdHUQ; visid_incap_1722501=z8YspOTjRLmNxY1jMdqc2voij14AAAAAQUIPAAAAAAAz5k9o0TPe5INp8+VLBGMZ; FRONTONE_USER=1589030911; FRONTONE_SESSID=b63750e3dfbafa4034d6cf3e8d2d558c; FRONTONE_SESSION_ID=e63380316c097c37050207ec718741fff9259edc; nlbi_441619=ufhBSxHyMEoXfsE3Jv8P3AAAAABTP2fpV1zP/JtDBdulhzAa; incap_ses_766_441619=MtovSnQkoT9/JNpoFmKhCqEbkF4AAAAAc7N3y/70ukqqav4TtYvpDQ==; pageCounterCrfOne=1; QueueITAccepted-SDFrts345E-V3_prodevent=EventId%3Dprodevent%26QueueId%3D54e303e1-7614-444d-8c92-dbdad2d61b4a%26RedirectType%3Dsafetynet%26IssueTime%3D1586502577%26Hash%3D21030c8a62ca512d24f5dcbcaacc1f41b3c042a6999d987071870a39842d6678
dnt: 1
pragma: no-cache
referer: https://www.carrefour.fr/promotions?noRedirect=1&page={i}
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36
x-requested-with: XMLHttpRequest"""
    headers=dict([i.split(': ') for i in headers.split('\n')])
    results=r.get(url, headers=headers).json()
    df=pd.json_normalize(results['data'])
    df['difference'] = df['attributes.promotion.messageArgs.initialPrice'] - df['attributes.promotion.messageArgs.discountedPrice']

    df1 = df[['attributes.ean','attributes.title', 'attributes.brand',  'attributes.categories','attributes.availability.purchasable', 'attributes.promotion.label', 'attributes.promotion.bestQuantity', 'attributes.promotion.messageArgs.discountedPrice','attributes.promotion.messageArgs.initialPrice', 'difference', 'attributes.promotion.discountLabel','attributes.price.perUnitLabel','attributes.promotion.promoStartDate','attributes.promotion.promoEndDate']]

    df_final=df_final.append(df1)
    time.sleep(2)
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
df_final=df_final.reset_index() 
df_final.rename(columns={"index":"old_index"})
# Out:
#      old_index attributes.ean  \
# 0            0  0000041007563
# 1            1  0000080135517
# 2            2  0000059945741
# 3            3  3292070009275
# 4            4  3292070008551
# ..         ...            ...
# 377         17  8001691494958
# 378         18  8001691494866
# 379         19  8001691494927
# 380         20  8421134090309
# 381         21  4039784342033
#
#                                       attributes.title  attributes.brand  \
# 0                      Chocolat de Pâques lapin NESTLE            NESTLE
# 1              Chocolat de Pâques au lait lapin KINDER            KINDER
# 2                       Chocolat de Pâques Œufs NESTLE            NESTLE
# 3                          Blinis bio x8 ATELIER BLINI  ATELIER DE BLINI
# 4                                   Houmous bio  BLINI  ATELIER DE BLINI
# ..                                                 ...               ...
# 377                    Verre  "Azulejos" à motif 36 cl        PP NO NAME
# 378               Verre  "Azulejos" à motif bleu 36 cl        PP NO NAME
# 379               Verre  "Azulejos" à motif bleu 36 cl        PP NO NAME
# 380  Poupée Magic Tears Fantasy Maison Tototte CRY ...          IMC TOYS
# 381  KARCHER - Détergent vitres formule 3-en-1 - 62...           KARCHER
#
#                                  attributes.categories  \
# 0    [{'id': 'R10', 'slug': 'epicerie-sucree', 'lab...
# 1    [{'id': 'R10', 'slug': 'epicerie-sucree', 'lab...
# 2    [{'id': 'R10', 'slug': 'epicerie-sucree', 'lab...
# 3    [{'id': 'R01', 'slug': 'bio-et-ecologie', 'lab...
# 4    [{'id': 'R01', 'slug': 'bio-et-ecologie', 'lab...
# ..                                                 ...
# 377  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 378  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 379  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 380  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 381  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
#
#      attributes.availability.purchasable attributes.promotion.label  \
# 0                                   True             Le 2ème à -50%
# 1                                   True             Le 2ème à -50%
# 2                                   True             Le 2ème à -50%
# 3                                   True   Prenez en 3 = Payez en 2
# 4                                   True   Prenez en 3 = Payez en 2
# ..                                   ...                        ...
# 377                                 True            Vu en catalogue
# 378                                 True            Vu en catalogue
# 379                                 True            Vu en catalogue
# 380                                 True            Vu en catalogue
# 381                                 True   Prenez en 4 = Payez en 3
#
#      attributes.promotion.bestQuantity  \
# 0                                    2
# 1                                    2
# 2                                    2
# 3                                    3
# 4                                    3
# ..                                 ...
# 377                                  1
# 378                                  1
# 379                                  1
# 380                                  1
# 381                                  4
#
#      attributes.promotion.messageArgs.discountedPrice  \
# 0                                                4.18
# 1                                                3.73
# 2                                                2.23
# 3                                                5.00
# 4                                                6.98
# ..                                                ...
# 377                                              1.60
# 378                                              1.60
# 379                                              1.60
# 380                                             17.90
# 381                                             16.50
#
#      attributes.promotion.messageArgs.initialPrice  difference  \
# 0                                             5.58        1.40
# 1                                             4.98        1.25
# 2                                             2.98        0.75
# 3                                             7.50        2.50
# 4                                            10.47        3.49
# ..                                             ...         ...
# 377                                           1.60        0.00
# 378                                           1.60        0.00
# 379                                           1.60        0.00
# 380                                          17.90        0.00
# 381                                          22.00        5.50
#
#     attributes.promotion.discountLabel attributes.price.perUnitLabel  \
# 0      soit 2 à 4.18€ au lieu de 5.58€          32.82 € / Kilogramme
# 1      soit 2 à 3.73€ au lieu de 4.98€          22.64 € / Kilogramme
# 2      soit 2 à 2.23€ au lieu de 2.98€          29.80 € / Kilogramme
# 3      soit 3 à 5.00€ au lieu de 7.50€          15.62 € / Kilogramme
# 4     soit 3 à 6.98€ au lieu de 10.47€          21.81 € / Kilogramme
# ..                                 ...                           ...
# 377    soit 1 à 1.60€ au lieu de 1.60€                1.60 € / Pièce
# 378    soit 1 à 1.60€ au lieu de 1.60€                1.60 € / Pièce
# 379    soit 1 à 1.60€ au lieu de 1.60€                1.60 € / Pièce
# 380  soit 1 à 17.90€ au lieu de 17.90€               17.90 € / Pièce
# 381  soit 4 à 16.50€ au lieu de 22.00€                5.50 € / Pièce
#
#     attributes.promotion.promoStartDate attributes.promotion.promoEndDate
# 0              2020-04-07T00:00:00+0200          2020-07-05T23:59:00+0200
# 1              2020-04-07T00:00:00+0200          2020-07-05T23:59:00+0200
# 2              2020-04-07T00:00:00+0200          2020-07-05T23:59:00+0200
# 3              2020-04-03T00:00:00+0200          2020-04-13T23:59:00+0200
# 4              2020-04-03T00:00:00+0200          2020-04-13T23:59:00+0200
# ..                                  ...                               ...
# 377            2020-03-24T00:00:00+0100          2020-04-27T23:59:00+0200
# 378            2020-03-24T00:00:00+0100          2020-04-27T23:59:00+0200
# 379            2020-03-24T00:00:00+0100          2020-04-27T23:59:00+0200
# 380            2020-03-31T00:00:00+0200          2020-04-14T23:59:00+0200
# 381            2020-03-31T00:00:00+0200          2020-04-13T23:59:00+0200
#
# [382 rows x 15 columns]

# %%
def clean_cat():

    categories=[]

    for k in df_final.index:
        categories.append([i['label'] for i in df_final['attributes.categories'][k]])
        category=[i[0] for i in categories]
        subcategory=[i[1] for i in categories]
    df_final['category']=category
    df_final['subcategory']=subcategory
    
    return df_final

# %%
clean_cat()
df_final
# Out:
#      index attributes.ean                                   attributes.title  \
# 0        0  0000041007563                    Chocolat de Pâques lapin NESTLE
# 1        1  0000080135517            Chocolat de Pâques au lait lapin KINDER
# 2        2  0000059945741                     Chocolat de Pâques Œufs NESTLE
# 3        3  3292070009275                        Blinis bio x8 ATELIER BLINI
# 4        4  3292070008551                                 Houmous bio  BLINI
# ..     ...            ...                                                ...
# 377     17  8001691494958                    Verre  "Azulejos" à motif 36 cl
# 378     18  8001691494866               Verre  "Azulejos" à motif bleu 36 cl
# 379     19  8001691494927               Verre  "Azulejos" à motif bleu 36 cl
# 380     20  8421134090309  Poupée Magic Tears Fantasy Maison Tototte CRY ...
# 381     21  4039784342033  KARCHER - Détergent vitres formule 3-en-1 - 62...
#
#      attributes.brand                              attributes.categories  \
# 0              NESTLE  [{'id': 'R10', 'slug': 'epicerie-sucree', 'lab...
# 1              KINDER  [{'id': 'R10', 'slug': 'epicerie-sucree', 'lab...
# 2              NESTLE  [{'id': 'R10', 'slug': 'epicerie-sucree', 'lab...
# 3    ATELIER DE BLINI  [{'id': 'R01', 'slug': 'bio-et-ecologie', 'lab...
# 4    ATELIER DE BLINI  [{'id': 'R01', 'slug': 'bio-et-ecologie', 'lab...
# ..                ...                                                ...
# 377        PP NO NAME  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 378        PP NO NAME  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 379        PP NO NAME  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 380          IMC TOYS  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
# 381           KARCHER  [{'id': 'R18', 'slug': 'maison-loisir-textile'...
#
#      attributes.availability.purchasable attributes.promotion.label  \
# 0                                   True             Le 2ème à -50%
# 1                                   True             Le 2ème à -50%
# 2                                   True             Le 2ème à -50%
# 3                                   True   Prenez en 3 = Payez en 2
# 4                                   True   Prenez en 3 = Payez en 2
# ..                                   ...                        ...
# 377                                 True            Vu en catalogue
# 378                                 True            Vu en catalogue
# 379                                 True            Vu en catalogue
# 380                                 True            Vu en catalogue
# 381                                 True   Prenez en 4 = Payez en 3
#
#      attributes.promotion.bestQuantity  \
# 0                                    2
# 1                                    2
# 2                                    2
# 3                                    3
# 4                                    3
# ..                                 ...
# 377                                  1
# 378                                  1
# 379                                  1
# 380                                  1
# 381                                  4
#
#      attributes.promotion.messageArgs.discountedPrice  \
# 0                                                4.18
# 1                                                3.73
# 2                                                2.23
# 3                                                5.00
# 4                                                6.98
# ..                                                ...
# 377                                              1.60
# 378                                              1.60
# 379                                              1.60
# 380                                             17.90
# 381                                             16.50
#
#      attributes.promotion.messageArgs.initialPrice  difference  \
# 0                                             5.58        1.40
# 1                                             4.98        1.25
# 2                                             2.98        0.75
# 3                                             7.50        2.50
# 4                                            10.47        3.49
# ..                                             ...         ...
# 377                                           1.60        0.00
# 378                                           1.60        0.00
# 379                                           1.60        0.00
# 380                                          17.90        0.00
# 381                                          22.00        5.50
#
#     attributes.promotion.discountLabel attributes.price.perUnitLabel  \
# 0      soit 2 à 4.18€ au lieu de 5.58€          32.82 € / Kilogramme
# 1      soit 2 à 3.73€ au lieu de 4.98€          22.64 € / Kilogramme
# 2      soit 2 à 2.23€ au lieu de 2.98€          29.80 € / Kilogramme
# 3      soit 3 à 5.00€ au lieu de 7.50€          15.62 € / Kilogramme
# 4     soit 3 à 6.98€ au lieu de 10.47€          21.81 € / Kilogramme
# ..                                 ...                           ...
# 377    soit 1 à 1.60€ au lieu de 1.60€                1.60 € / Pièce
# 378    soit 1 à 1.60€ au lieu de 1.60€                1.60 € / Pièce
# 379    soit 1 à 1.60€ au lieu de 1.60€                1.60 € / Pièce
# 380  soit 1 à 17.90€ au lieu de 17.90€               17.90 € / Pièce
# 381  soit 4 à 16.50€ au lieu de 22.00€                5.50 € / Pièce
#
#     attributes.promotion.promoStartDate attributes.promotion.promoEndDate  \
# 0              2020-04-07T00:00:00+0200          2020-07-05T23:59:00+0200
# 1              2020-04-07T00:00:00+0200          2020-07-05T23:59:00+0200
# 2              2020-04-07T00:00:00+0200          2020-07-05T23:59:00+0200
# 3              2020-04-03T00:00:00+0200          2020-04-13T23:59:00+0200
# 4              2020-04-03T00:00:00+0200          2020-04-13T23:59:00+0200
# ..                                  ...                               ...
# 377            2020-03-24T00:00:00+0100          2020-04-27T23:59:00+0200
# 378            2020-03-24T00:00:00+0100          2020-04-27T23:59:00+0200
# 379            2020-03-24T00:00:00+0100          2020-04-27T23:59:00+0200
# 380            2020-03-31T00:00:00+0200          2020-04-14T23:59:00+0200
# 381            2020-03-31T00:00:00+0200          2020-04-13T23:59:00+0200
#
#                     category                subcategory
# 0            Epicerie Sucrée        Chocolats de pâques
# 1            Epicerie Sucrée        Chocolats de pâques
# 2            Epicerie Sucrée        Chocolats de pâques
# 3            Bio et Ecologie          Frais et surgelés
# 4            Bio et Ecologie          Frais et surgelés
# ..                       ...                        ...
# 377  Maison, Loisir, Textile                    Cuisine
# 378  Maison, Loisir, Textile                    Cuisine
# 379  Maison, Loisir, Textile                    Cuisine
# 380  Maison, Loisir, Textile             Jeux et Jouets
# 381  Maison, Loisir, Textile  Bricolage, auto et jardin
#
# [382 rows x 17 columns]

# %%
df_final=df_final.drop(['attributes.categories'], axis=1)

# %%
def renaming_col(df_final):
    df_ok=df_final.rename(columns={"attributes.ean": "EAN", "attributes.title": "product_name", 'attributes.brand':'brand', 'attributes.availability.purchasable':'purchasable', 'attributes.promotion.label':'promotion_type', 'attributes.promotion.bestQuantity': 'best_quantity', 'attributes.promotion.messageArgs.discountedPrice': 'discounted_price', 'attributes.promotion.messageArgs.initialPrice':'initial_price', 'attributes.promotion.discountLabel':'promo_description','attributes.price.perUnitLabel':'price_per_unit','attributes.promotion.promoStartDate':'Start_Date', 'attributes.promotion.promoEndDate':'End_Date'   })
    df_ok=df_ok[['EAN', 'product_name', 'brand', 'category', 'subcategory', 'purchasable', 'promotion_type', 'promo_description', 'best_quantity','price_per_unit', 'discounted_price', 'initial_price', 'difference','Start_Date','End_Date']]
    return df_ok

# %%
df_final=renaming_col(df_final)

# %%
df_final
# Out:
#                EAN                                       product_name  \
# 0    0000041007563                    Chocolat de Pâques lapin NESTLE
# 1    0000080135517            Chocolat de Pâques au lait lapin KINDER
# 2    0000059945741                     Chocolat de Pâques Œufs NESTLE
# 3    3292070009275                        Blinis bio x8 ATELIER BLINI
# 4    3292070008551                                 Houmous bio  BLINI
# ..             ...                                                ...
# 377  8001691494958                    Verre  "Azulejos" à motif 36 cl
# 378  8001691494866               Verre  "Azulejos" à motif bleu 36 cl
# 379  8001691494927               Verre  "Azulejos" à motif bleu 36 cl
# 380  8421134090309  Poupée Magic Tears Fantasy Maison Tototte CRY ...
# 381  4039784342033  KARCHER - Détergent vitres formule 3-en-1 - 62...
#
#                 brand                 category                subcategory  \
# 0              NESTLE          Epicerie Sucrée        Chocolats de pâques
# 1              KINDER          Epicerie Sucrée        Chocolats de pâques
# 2              NESTLE          Epicerie Sucrée        Chocolats de pâques
# 3    ATELIER DE BLINI          Bio et Ecologie          Frais et surgelés
# 4    ATELIER DE BLINI          Bio et Ecologie          Frais et surgelés
# ..                ...                      ...                        ...
# 377        PP NO NAME  Maison, Loisir, Textile                    Cuisine
# 378        PP NO NAME  Maison, Loisir, Textile                    Cuisine
# 379        PP NO NAME  Maison, Loisir, Textile                    Cuisine
# 380          IMC TOYS  Maison, Loisir, Textile             Jeux et Jouets
# 381           KARCHER  Maison, Loisir, Textile  Bricolage, auto et jardin
#
#      purchasable            promotion_type                  promo_description  \
# 0           True            Le 2ème à -50%    soit 2 à 4.18€ au lieu de 5.58€
# 1           True            Le 2ème à -50%    soit 2 à 3.73€ au lieu de 4.98€
# 2           True            Le 2ème à -50%    soit 2 à 2.23€ au lieu de 2.98€
# 3           True  Prenez en 3 = Payez en 2    soit 3 à 5.00€ au lieu de 7.50€
# 4           True  Prenez en 3 = Payez en 2   soit 3 à 6.98€ au lieu de 10.47€
# ..           ...                       ...                                ...
# 377         True           Vu en catalogue    soit 1 à 1.60€ au lieu de 1.60€
# 378         True           Vu en catalogue    soit 1 à 1.60€ au lieu de 1.60€
# 379         True           Vu en catalogue    soit 1 à 1.60€ au lieu de 1.60€
# 380         True           Vu en catalogue  soit 1 à 17.90€ au lieu de 17.90€
# 381         True  Prenez en 4 = Payez en 3  soit 4 à 16.50€ au lieu de 22.00€
#
#      best_quantity        price_per_unit  discounted_price  initial_price  \
# 0                2  32.82 € / Kilogramme              4.18           5.58
# 1                2  22.64 € / Kilogramme              3.73           4.98
# 2                2  29.80 € / Kilogramme              2.23           2.98
# 3                3  15.62 € / Kilogramme              5.00           7.50
# 4                3  21.81 € / Kilogramme              6.98          10.47
# ..             ...                   ...               ...            ...
# 377              1        1.60 € / Pièce              1.60           1.60
# 378              1        1.60 € / Pièce              1.60           1.60
# 379              1        1.60 € / Pièce              1.60           1.60
# 380              1       17.90 € / Pièce             17.90          17.90
# 381              4        5.50 € / Pièce             16.50          22.00
#
#      difference                Start_Date                  End_Date
# 0          1.40  2020-04-07T00:00:00+0200  2020-07-05T23:59:00+0200
# 1          1.25  2020-04-07T00:00:00+0200  2020-07-05T23:59:00+0200
# 2          0.75  2020-04-07T00:00:00+0200  2020-07-05T23:59:00+0200
# 3          2.50  2020-04-03T00:00:00+0200  2020-04-13T23:59:00+0200
# 4          3.49  2020-04-03T00:00:00+0200  2020-04-13T23:59:00+0200
# ..          ...                       ...                       ...
# 377        0.00  2020-03-24T00:00:00+0100  2020-04-27T23:59:00+0200
# 378        0.00  2020-03-24T00:00:00+0100  2020-04-27T23:59:00+0200
# 379        0.00  2020-03-24T00:00:00+0100  2020-04-27T23:59:00+0200
# 380        0.00  2020-03-31T00:00:00+0200  2020-04-14T23:59:00+0200
# 381        5.50  2020-03-31T00:00:00+0200  2020-04-13T23:59:00+0200
#
# [382 rows x 15 columns]

# %%
df_final.groupby('category').mean()
# Out:
#                          purchasable  best_quantity  discounted_price  \
# category
# Bio et Ecologie                 True       1.800000          6.005000
# Crémerie                        True       1.000000          4.226667
# Epicerie Sucrée                 True       2.000000          3.380000
# Fruits et Légumes               True       1.285714          3.178571
# Maison, Loisir, Textile         True       1.108108          7.946216
# Pains et Pâtisseries            True       1.000000         11.522222
# Traiteur                        True       1.781609          7.008908
# Viandes et Poissons             True       1.593750          8.589062
#
#                          initial_price  difference
# category
# Bio et Ecologie               8.760000    2.755000
# Crémerie                      4.226667    0.000000
# Epicerie Sucrée               4.513333    1.133333
# Fruits et Légumes             3.344286    0.165714
# Maison, Loisir, Textile       8.162432    0.216216
# Pains et Pâtisseries         11.522222    0.000000
# Traiteur                      9.263678    2.254770
# Viandes et Poissons          11.197813    2.608750

# %%
df_group=df_final.groupby(['category','subcategory']).count()['EAN']
df_group=pd.DataFrame(df_group).rename(columns={'EAN':'count_promotion'})
df_group
# Out:
#                                                                     count_promotion
# category                subcategory
# Bio et Ecologie         Epicerie sucrée                                           2
#                         Frais et surgelés                                        18
# Crémerie                Fromages                                                 10
#                         Yaourts, desserts et spécialités végétales                2
# Epicerie Sucrée         Chocolats de pâques                                       6
# Fruits et Légumes       Fruits                                                    2
#                         Légumes                                                  12
# Maison, Loisir, Textile Bricolage, auto et jardin                                 3
#                         Cartouche, électronique et culture                        1
#                         Cuisine                                                  63
#                         Jeux et Jouets                                            7
# Pains et Pâtisseries    Mon pâtissier                                            18
# Traiteur                Apéritif et cocktail dînatoire                            4
#                         Pâques                                                  168
#                         Traiteur de la Mer                                        1
#                         Traiteur traditionnel                                     1
# Viandes et Poissons     Boucherie                                                 6
#                         Poissonnerie                                             50
#                         Volaille et Rôtisserie                                    8

# %% [markdown]
# # Output

# %%
# save final df into a csv
def save_df():
    os.chdir('C:/Users/Camille/Documents/Ecole/Ironhack/Week 3/Web_Scrapping_project/Output')
    df_final.to_csv('Carrefour_promo.csv')

# %%
save_df()

# %%
# compute number of promo that aren't promo
# count number of 0 in column difference
# pd.Series(df_final.difference.value_counts())

dfnull=df_final.loc[df_final['difference'] == float(0)]
len(dfnull)
# Out:
# 152

# %%
def graph_subcat():
    subcat=pd.Series(df_final.subcategory.value_counts()).plot.bar(fontsize=10, figsize=(15, 10)).set_title('Promotions per subcategory', fontsize=15)
    return subcat

def graph_top_brands():
    top_brands=pd.Series(df_final.brand.value_counts()).nlargest(10)
    brands=top_brands.plot.bar(fontsize=10, figsize=(15, 10)).set_title('Top 10 brands', fontsize=15)
    return brands

# %%
subcat=graph_subcat()

# %%
top_brands=graph_top_brands()

# %%
#Saving the charts in Output

def save_viz(barchart,title):
    os.chdir('C:/Users/Camille/Documents/Ecole/Ironhack/Week 3/Web_Scrapping_project/Output')
    fig = barchart.get_figure()
    fig.savefig(title+ '.png')
    plt.show()

# %%
save_viz(subcat,'Promotions per subcategory' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-082d5879630e> in <module>
# ----> 1 save_viz(subcat,'Promotions per subcategory' )
#
# <ipython-input-23-aff6f010c031> in save_viz(barchart, title)
#       5     fig = barchart.get_figure()
#       6     fig.savefig(title+ '.png')
# ----> 7     plt.show()
#
# NameError: name 'plt' is not defined

# %%
save_viz(top_brands, 'Promotion per brands (Top 10)')
